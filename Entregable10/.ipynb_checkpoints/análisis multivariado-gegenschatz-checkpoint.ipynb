# %%
# Importamos las librerías estándar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import math

# %%
# Descargamos los datos
url = 'https://drive.google.com/file/d/1lqdL5E3pjC0ISjsEe_F1N8xIKK8y-0nz/view?usp=sharing'
file_id = url.split('/')[-2]
download_url = 'https://drive.google.com/uc?id=' + file_id

df = pd.read_csv(download_url)

# %%
# Link al repo con información adicional
# https://github.com/santy-gegenschatz/CoderHouse-25570-Proyecto-Spotify

# %%
# Limpiamos los datos
df = df.set_index('id')
df = df.dropna()
df = df.drop_duplicates()
df.shape
# Out:
# (39837, 44)

# %%
# Describimos los datos
df.describe(include = 'all').T
# Out:
#                 count unique                  top  freq           mean  \
# name            39837  38054        Greatest Hits    46            NaN
# release_date    39837   7338           2021-09-03   189            NaN
# artists         39837  24770    Various Artists,   1592            NaN
# total_tracks  39837.0    NaN                  NaN   NaN      13.857796
# t_name0         39837  34878                Intro  1045            NaN
# t_name1         39837  36158  Remembered Meetings    11            NaN
# t_name2         39837  36350                 Time    13            NaN
# t_dur0        39837.0    NaN                  NaN   NaN  213221.532721
# t_dur1        39837.0    NaN                  NaN   NaN  222159.833471
# t_dur2        39837.0    NaN                  NaN   NaN  221847.772498
# t_dance0      39837.0    NaN                  NaN   NaN       0.569091
# t_dance1      39837.0    NaN                  NaN   NaN       0.591304
# t_dance2      39837.0    NaN                  NaN   NaN       0.591431
# t_energy0     39837.0    NaN                  NaN   NaN       0.588915
# t_energy1     39837.0    NaN                  NaN   NaN       0.605467
# t_energy2     39837.0    NaN                  NaN   NaN       0.595003
# t_key0        39837.0    NaN                  NaN   NaN       5.221503
# t_key1        39837.0    NaN                  NaN   NaN       5.230364
# t_key2        39837.0    NaN                  NaN   NaN       5.236941
# t_mode0       39837.0    NaN                  NaN   NaN       0.618922
# t_mode1       39837.0    NaN                  NaN   NaN       0.616713
# t_mode2       39837.0    NaN                  NaN   NaN       0.616236
# t_speech0     39837.0    NaN                  NaN   NaN       0.126837
# t_speech1     39837.0    NaN                  NaN   NaN       0.119047
# t_speech2     39837.0    NaN                  NaN   NaN        0.11929
# t_acous0      39837.0    NaN                  NaN   NaN       0.337713
# t_acous1      39837.0    NaN                  NaN   NaN       0.310004
# t_acous2      39837.0    NaN                  NaN   NaN       0.319564
# t_ins0        39837.0    NaN                  NaN   NaN       0.209016
# t_ins1        39837.0    NaN                  NaN   NaN        0.19089
# t_ins2        39837.0    NaN                  NaN   NaN       0.195328
# t_live0       39837.0    NaN                  NaN   NaN       0.209144
# t_live1       39837.0    NaN                  NaN   NaN       0.198087
# t_live2       39837.0    NaN                  NaN   NaN       0.196666
# t_val0        39837.0    NaN                  NaN   NaN       0.465272
# t_val1        39837.0    NaN                  NaN   NaN       0.487286
# t_val2        39837.0    NaN                  NaN   NaN        0.48141
# t_tempo0      39837.0    NaN                  NaN   NaN     119.301313
# t_tempo1      39837.0    NaN                  NaN   NaN     120.601491
# t_tempo2      39837.0    NaN                  NaN   NaN     120.631454
# t_sig0        39837.0    NaN                  NaN   NaN       3.874388
# t_sig1        39837.0    NaN                  NaN   NaN       3.896252
# t_sig2        39837.0    NaN                  NaN   NaN       3.889776
# popularity    39837.0    NaN                  NaN   NaN        34.3007
#
#                         std     min       25%       50%       75%        max
# name                    NaN     NaN       NaN       NaN       NaN        NaN
# release_date            NaN     NaN       NaN       NaN       NaN        NaN
# artists                 NaN     NaN       NaN       NaN       NaN        NaN
# total_tracks      18.835366     3.0       8.0      12.0      15.0     1190.0
# t_name0                 NaN     NaN       NaN       NaN       NaN        NaN
# t_name1                 NaN     NaN       NaN       NaN       NaN        NaN
# t_name2                 NaN     NaN       NaN       NaN       NaN        NaN
# t_dur0        139486.047759  1485.0  147792.0  200026.0  251666.0  4449616.0
# t_dur1        128179.878397  4120.0  166335.0  207826.0  254302.0  7054236.0
# t_dur2        117355.183524  4285.0  166053.0  208538.0  256040.0  4520334.0
# t_dance0           0.190296     0.0     0.447     0.591     0.713      0.988
# t_dance1           0.184816     0.0     0.476     0.614     0.729      0.992
# t_dance2           0.184972     0.0     0.475     0.614     0.731      0.982
# t_energy0          0.254084     0.0     0.413     0.619     0.797        1.0
# t_energy1          0.248591     0.0     0.445     0.638     0.806        1.0
# t_energy2          0.248774     0.0     0.429     0.625     0.795        1.0
# t_key0             3.579044     0.0       2.0       5.0       8.0       11.0
# t_key1             3.592078     0.0       2.0       5.0       8.0       11.0
# t_key2             3.588924     0.0       2.0       5.0       8.0       11.0
# t_mode0            0.485658     0.0       0.0       1.0       1.0        1.0
# t_mode1            0.486193     0.0       0.0       1.0       1.0        1.0
# t_mode2            0.486308     0.0       0.0       1.0       1.0        1.0
# t_speech0          0.157119     0.0    0.0387    0.0571     0.143      0.968
# t_speech1          0.140136     0.0    0.0387    0.0575     0.138      0.971
# t_speech2          0.141803     0.0    0.0382    0.0567     0.139       0.97
# t_acous0           0.333245     0.0    0.0329     0.213     0.621      0.996
# t_acous1           0.322898     0.0     0.027     0.179     0.549      0.996
# t_acous2           0.326042     0.0    0.0299      0.19      0.57      0.996
# t_ins0             0.348187     0.0       0.0  0.000146      0.32        1.0
# t_ins1             0.337365     0.0       0.0  0.000073     0.181        1.0
# t_ins2             0.341005     0.0       0.0   0.00007     0.204        1.0
# t_live0            0.178775     0.0    0.0981     0.132     0.274      0.995
# t_live1              0.1689     0.0    0.0968     0.127      0.25      0.998
# t_live2             0.16783     0.0    0.0972     0.126     0.246      0.996
# t_val0             0.268932     0.0     0.239     0.456     0.682        1.0
# t_val1             0.261127     0.0     0.278     0.488     0.694        1.0
# t_val2             0.261099     0.0      0.27     0.478      0.69        1.0
# t_tempo0          31.259544     0.0    95.043   119.907   139.974    239.713
# t_tempo1          30.523359     0.0    96.069   119.996   140.038      248.5
# t_tempo2          30.622465     0.0    96.033   120.007   140.045    246.322
# t_sig0             0.539983     0.0       4.0       4.0       4.0        5.0
# t_sig1             0.466258     0.0       4.0       4.0       4.0        5.0
# t_sig2             0.487184     0.0       4.0       4.0       4.0        5.0
# popularity        18.865328     1.0      19.0      34.0      49.0      100.0

# %%
# Antes de hacer el análisis, vamos a hacer una variable que promedie cada una de las 3 variables diferentes por álbum
df['average_duration'] = ( df['t_dur0'] + df['t_dur1'] + df['t_dur2'] ) / 3
df['average_dance'] = ( df['t_dance0'] + df['t_dance1'] + df['t_dance2'] ) / 3
df['average_energy'] = ( df['t_energy0'] + df['t_energy1'] + df['t_energy2'] ) / 3
df['average_mode'] = ( df['t_mode0'] + df['t_mode1'] + df['t_mode2'] ) / 3
df['average_speech'] = ( df['t_speech0'] + df['t_speech1'] + df['t_speech2'] ) / 3
df['average_acous'] = ( df['t_acous0'] + df['t_acous1'] + df['t_acous2'] ) / 3
df['average_ins'] = ( df['t_ins0'] + df['t_ins1'] + df['t_ins2'] ) / 3
df['average_live'] = ( df['t_live0'] + df['t_live1'] + df['t_live2'] ) / 3
df['average_val'] = ( df['t_val0'] + df['t_val1'] + df['t_val2'] ) / 3
df['average_tempo'] = ( df['t_tempo0'] + df['t_tempo1'] + df['t_tempo2'] ) / 3
df['average_sig'] = ( df['t_sig0'] + df['t_sig1'] + df['t_sig2'] ) / 3

# %%
df.describe().T
# Out:
#                     count           mean            std          min  \
# total_tracks      39837.0      13.857796      18.835366     3.000000
# t_dur0            39837.0  213221.532721  139486.047759  1485.000000
# t_dur1            39837.0  222159.833471  128179.878397  4120.000000
# t_dur2            39837.0  221847.772498  117355.183524  4285.000000
# t_dance0          39837.0       0.569091       0.190296     0.000000
# t_dance1          39837.0       0.591304       0.184816     0.000000
# t_dance2          39837.0       0.591431       0.184972     0.000000
# t_energy0         39837.0       0.588915       0.254084     0.000000
# t_energy1         39837.0       0.605467       0.248591     0.000000
# t_energy2         39837.0       0.595003       0.248774     0.000000
# t_key0            39837.0       5.221503       3.579044     0.000000
# t_key1            39837.0       5.230364       3.592078     0.000000
# t_key2            39837.0       5.236941       3.588924     0.000000
# t_mode0           39837.0       0.618922       0.485658     0.000000
# t_mode1           39837.0       0.616713       0.486193     0.000000
# t_mode2           39837.0       0.616236       0.486308     0.000000
# t_speech0         39837.0       0.126837       0.157119     0.000000
# t_speech1         39837.0       0.119047       0.140136     0.000000
# t_speech2         39837.0       0.119290       0.141803     0.000000
# t_acous0          39837.0       0.337713       0.333245     0.000000
# t_acous1          39837.0       0.310004       0.322898     0.000000
# t_acous2          39837.0       0.319564       0.326042     0.000000
# t_ins0            39837.0       0.209016       0.348187     0.000000
# t_ins1            39837.0       0.190890       0.337365     0.000000
# t_ins2            39837.0       0.195328       0.341005     0.000000
# t_live0           39837.0       0.209144       0.178775     0.000000
# t_live1           39837.0       0.198087       0.168900     0.000000
# t_live2           39837.0       0.196666       0.167830     0.000000
# t_val0            39837.0       0.465272       0.268932     0.000000
# t_val1            39837.0       0.487286       0.261127     0.000000
# t_val2            39837.0       0.481410       0.261099     0.000000
# t_tempo0          39837.0     119.301313      31.259544     0.000000
# t_tempo1          39837.0     120.601491      30.523359     0.000000
# t_tempo2          39837.0     120.631454      30.622465     0.000000
# t_sig0            39837.0       3.874388       0.539983     0.000000
# t_sig1            39837.0       3.896252       0.466258     0.000000
# t_sig2            39837.0       3.889776       0.487184     0.000000
# popularity        39837.0      34.300700      18.865328     1.000000
# average_duration  39837.0  219076.379563  109679.542284  8759.666667
# average_dance     39837.0       0.583942       0.160861     0.000000
# average_energy    39837.0       0.596462       0.223027     0.000000
# average_mode      39837.0       0.617290       0.315055     0.000000
# average_speech    39837.0       0.121725       0.126113     0.000000
# average_acous     39837.0       0.322427       0.287263     0.000000
# average_ins       39837.0       0.198411       0.309667     0.000000
# average_live      39837.0       0.201299       0.129410     0.000000
# average_val       39837.0       0.477989       0.214907     0.000000
# average_tempo     39837.0     120.178086      20.062597     0.000000
# average_sig       39837.0       3.886805       0.322021     0.000000
#
#                             25%            50%            75%           max
# total_tracks           8.000000      12.000000      15.000000  1.190000e+03
# t_dur0            147792.000000  200026.000000  251666.000000  4.449616e+06
# t_dur1            166335.000000  207826.000000  254302.000000  7.054236e+06
# t_dur2            166053.000000  208538.000000  256040.000000  4.520334e+06
# t_dance0               0.447000       0.591000       0.713000  9.880000e-01
# t_dance1               0.476000       0.614000       0.729000  9.920000e-01
# t_dance2               0.475000       0.614000       0.731000  9.820000e-01
# t_energy0              0.413000       0.619000       0.797000  1.000000e+00
# t_energy1              0.445000       0.638000       0.806000  1.000000e+00
# t_energy2              0.429000       0.625000       0.795000  1.000000e+00
# t_key0                 2.000000       5.000000       8.000000  1.100000e+01
# t_key1                 2.000000       5.000000       8.000000  1.100000e+01
# t_key2                 2.000000       5.000000       8.000000  1.100000e+01
# t_mode0                0.000000       1.000000       1.000000  1.000000e+00
# t_mode1                0.000000       1.000000       1.000000  1.000000e+00
# t_mode2                0.000000       1.000000       1.000000  1.000000e+00
# t_speech0              0.038700       0.057100       0.143000  9.680000e-01
# t_speech1              0.038700       0.057500       0.138000  9.710000e-01
# t_speech2              0.038200       0.056700       0.139000  9.700000e-01
# t_acous0               0.032900       0.213000       0.621000  9.960000e-01
# t_acous1               0.027000       0.179000       0.549000  9.960000e-01
# t_acous2               0.029900       0.190000       0.570000  9.960000e-01
# t_ins0                 0.000000       0.000146       0.320000  1.000000e+00
# t_ins1                 0.000000       0.000073       0.181000  1.000000e+00
# t_ins2                 0.000000       0.000070       0.204000  1.000000e+00
# t_live0                0.098100       0.132000       0.274000  9.950000e-01
# t_live1                0.096800       0.127000       0.250000  9.980000e-01
# t_live2                0.097200       0.126000       0.246000  9.960000e-01
# t_val0                 0.239000       0.456000       0.682000  1.000000e+00
# t_val1                 0.278000       0.488000       0.694000  1.000000e+00
# t_val2                 0.270000       0.478000       0.690000  1.000000e+00
# t_tempo0              95.043000     119.907000     139.974000  2.397130e+02
# t_tempo1              96.069000     119.996000     140.038000  2.485000e+02
# t_tempo2              96.033000     120.007000     140.045000  2.463220e+02
# t_sig0                 4.000000       4.000000       4.000000  5.000000e+00
# t_sig1                 4.000000       4.000000       4.000000  5.000000e+00
# t_sig2                 4.000000       4.000000       4.000000  5.000000e+00
# popularity            19.000000      34.000000      49.000000  1.000000e+02
# average_duration  167026.333333  205177.333333  248097.666667  3.678824e+06
# average_dance          0.485333       0.604000       0.702667  9.733333e-01
# average_energy         0.461333       0.624333       0.763667  1.000000e+00
# average_mode           0.333333       0.666667       1.000000  1.000000e+00
# average_speech         0.043200       0.067600       0.155367  9.650000e-01
# average_acous          0.077243       0.246067       0.504333  9.960000e-01
# average_ins            0.000005       0.002192       0.312232  9.980000e-01
# average_live           0.115333       0.165333       0.240333  9.876667e-01
# average_val            0.324000       0.478000       0.633000  9.846667e-01
# average_tempo        106.645667     120.322667     133.349667  2.049747e+02
# average_sig            4.000000       4.000000       4.000000  5.000000e+00

# %%
# Ahora hacemos un nuevo dataframe con las columnas promediadas y la columna de salida (popularity)
df2 = df[['average_duration', 'average_dance', 'average_energy', 'average_mode', 'average_speech', 'average_acous', 'average_live', 'average_val', 'average_tempo', 'average_sig', 'popularity']].copy()

# %%
df2.describe().T
# Out:
#                     count           mean            std          min  \
# average_duration  39837.0  219076.379563  109679.542284  8759.666667
# average_dance     39837.0       0.583942       0.160861     0.000000
# average_energy    39837.0       0.596462       0.223027     0.000000
# average_mode      39837.0       0.617290       0.315055     0.000000
# average_speech    39837.0       0.121725       0.126113     0.000000
# average_acous     39837.0       0.322427       0.287263     0.000000
# average_live      39837.0       0.201299       0.129410     0.000000
# average_val       39837.0       0.477989       0.214907     0.000000
# average_tempo     39837.0     120.178086      20.062597     0.000000
# average_sig       39837.0       3.886805       0.322021     0.000000
# popularity        39837.0      34.300700      18.865328     1.000000
#
#                             25%            50%            75%           max
# average_duration  167026.333333  205177.333333  248097.666667  3.678824e+06
# average_dance          0.485333       0.604000       0.702667  9.733333e-01
# average_energy         0.461333       0.624333       0.763667  1.000000e+00
# average_mode           0.333333       0.666667       1.000000  1.000000e+00
# average_speech         0.043200       0.067600       0.155367  9.650000e-01
# average_acous          0.077243       0.246067       0.504333  9.960000e-01
# average_live           0.115333       0.165333       0.240333  9.876667e-01
# average_val            0.324000       0.478000       0.633000  9.846667e-01
# average_tempo        106.645667     120.322667     133.349667  2.049747e+02
# average_sig            4.000000       4.000000       4.000000  5.000000e+00
# popularity            19.000000      34.000000      49.000000  1.000000e+02

# %%
# Para el análisis multivariado, vamos a realizar 3 gráficos.
# Uno es un pairplot, otro es un gráifco radial y otro es un gráfico en 3d.

# %% [markdown]
# ## Pairplot

# %%
# Para el pairplot vamos a tomar la categoría popularity y la vamos a partir en tres, y vamos a graficar el pairplot con un hue de cada una de esas 3 categorías

# %%
def categorize(value):
    if (value <= 33):
        return "LOW"
    elif (value <= 67):
        return "MEDIUM"
    else:
        return "HIGH"

# %%
df2['type_of_popularity'] = df2['popularity'].apply(lambda value: categorize(value))

# %%
df2.head()
# Out:
#     average_duration  average_dance  average_energy  average_mode  \
# id
# 0      192284.000000       0.536667        0.458667      0.666667
# 1      195199.666667       0.779000        0.658333      0.000000
# 2      154768.333333       0.555000        0.487000      0.666667
# 3      203866.333333       0.628333        0.585000      1.000000
# 4      140693.000000       0.638000        0.302333      1.000000
#
#     average_speech  average_acous  average_live  average_val  average_tempo  \
# id
# 0         0.048967       0.490333      0.091233     0.779000     133.243333
# 1         0.202100       0.109367      0.114333     0.413333     139.028000
# 2         0.272667       0.240847      0.286733     0.521333     122.268667
# 3         0.027467       0.333333      0.203333     0.556333     114.783333
# 4         0.071500       0.711333      0.270667     0.533000     116.460000
#
#     average_sig  popularity type_of_popularity
# id
# 0      3.333333          51             MEDIUM
# 1      4.000000          67             MEDIUM
# 2      4.000000          81               HIGH
# 3      4.000000          53             MEDIUM
# 4      4.000000          70               HIGH

# %%
# Ahora que ya está todo partido, vamos a graficar
plt.figure(figsize = (20, 14))
# El df2 tiene muchas columnas, asi que vamos a generar un df3 con las que realmente queremos ver
df3 = df2.iloc[ : , 5:]
sns.pairplot(df3, hue = 'type_of_popularity')
plt.title('Pairplot de las variables principales, teñidas por el tipo de popularidad')
# Out:
# Text(0.5, 1, 'Pairplot de las variables principales, teñidas por el tipo de popularidad')

# %% [markdown]
# ## Gráfico de Radar

# %% [markdown]
# ## Gráfico 3D

# %%
import plotly.express as px

# Antes de hacer el gráfico vemos el problema de que serían muichas filas y explotaría la compu, 
# asi que redefinimos un df_3d para imprimir en 3d

df_3d = df2.iloc[:5000, :]

# Gráfico en 3 dimensiones
fig = px.scatter_3d(df_3d, x='average_dance', y='average_speech', z='average_tempo', size='average_duration',
              color='type_of_popularity', opacity=0.8)

fig.update_layout(margin=dict(l=0, r=0, b=0, t=0),
                  title={
        'text': "Gráfico 3D de los atributos de las canciones",
        'y':0.9,
        'x':0.05
         })
fig.show()
# Out:
# <div>                            <div id="c4a9d9c2-9eb8-4724-9b40-8ae6cac01c2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4a9d9c2-9eb8-4724-9b40-8ae6cac01c2e")) {                    Plotly.newPlot(                        "c4a9d9c2-9eb8-4724-9b40-8ae6cac01c2e",                        [{"hovertemplate":"type_of_popularity=MEDIUM<br>average_dance=%{x}<br>average_speech=%{y}<br>average_tempo=%{z}<br>average_duration=%{marker.size}<extra></extra>","legendgroup":"MEDIUM","marker":{"color":"#636efa","opacity":0.8,"size":[192284.0,195199.66666666666,203866.33333333334,93391.0,327288.3333333333,179653.0,120852.66666666667,204857.33333333334,179395.33333333334,223075.0,172937.0,165478.33333333334,242225.0,121355.33333333333,309457.6666666667,185822.0,230488.66666666666,242613.0,205005.33333333334,235955.33333333334,253964.0,191251.66666666666,199311.66666666666,204564.33333333334,188399.66666666666,238924.0,145282.66666666666,132466.66666666666,276195.0,206355.0,265208.6666666667,207359.66666666666,212350.66666666666,155494.33333333334,163484.0,209195.33333333334,148715.66666666666,247844.33333333334,289902.0,171996.33333333334,247402.33333333334,154075.66666666666,230199.33333333334,174586.33333333334,204732.0,223066.33333333334,401351.6666666667,189007.66666666666,242412.66666666666,206866.66666666666,185297.66666666666,205137.33333333334,137818.0,243746.33333333334,222417.33333333334,216537.66666666666,167844.0,206239.66666666666,145031.33333333334,260510.66666666666,146573.0,326088.6666666667,225000.0,215764.66666666666,285999.6666666667,232710.66666666666,247372.66666666666,215341.66666666666,188719.66666666666,205942.0,122689.0,256881.33333333334,184897.0,122650.33333333333,157207.33333333334,225000.33333333334,264084.0,197413.0,201145.0,247848.33333333334,166515.33333333334,152545.66666666666,212639.66666666666,192355.33333333334,214906.33333333334,205831.0,260219.66666666666,265422.0,201142.33333333334,193525.0,145616.66666666666,166887.0,185096.33333333334,215306.0,321155.3333333333,181697.33333333334,191507.0,186613.0,206555.33333333334,242755.33333333334,237999.66666666666,132862.0,208364.33333333334,242297.33333333334,191968.66666666666,183507.0,202755.33333333334,185866.33333333334,236528.33333333334,190968.0,217541.66666666666,159189.66666666666,182710.66666666666,145437.33333333334,214777.33333333334,118284.66666666667,394799.6666666667,168857.33333333334,195667.66666666666,106287.0,209551.33333333334,146244.33333333334,265169.0,228757.33333333334,234500.33333333334,201620.33333333334,151609.0,245186.33333333334,136151.33333333334,190213.0,306830.6666666667,187273.66666666666,169610.33333333334,129386.33333333333,175257.0,260226.33333333334,234190.66666666666,136603.66666666666,191755.33333333334,228008.66666666666,244488.33333333334,100851.66666666667,277821.6666666667,99427.66666666667,201782.0,166297.66666666666,233044.33333333334,192800.66666666666,217977.66666666666,212307.33333333334,193388.0,162059.0,165811.0,214275.33333333334,172848.66666666666,209039.66666666666,145237.33333333334,293719.6666666667,288866.3333333333,256305.33333333334,252995.0,184509.33333333334,261161.33333333334,223164.0,223324.0,233083.33333333334,172873.66666666666,215057.33333333334,252439.33333333334,189857.33333333334,288986.6666666667,247857.66666666666,208991.0,112500.0,187319.66666666666,194962.0,129666.33333333333,182416.66666666666,156510.66666666666,205609.66666666666,177927.0,175098.33333333334,308915.0,210239.66666666666,179913.66666666666,280545.3333333333,187285.66666666666,274884.3333333333,114950.66666666667,131083.66666666666,235854.33333333334,190684.0,295377.6666666667,379124.0,205311.0,231171.0,160612.0,187998.66666666666,204511.0,185920.33333333334,209806.66666666666,208128.666666 ...
